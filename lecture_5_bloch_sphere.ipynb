# %% [markdown]
# ## Qubits, the Bloch Sphere, and Basis States

# %% [markdown]
# ## Installs and Imports
#
# We will need to install Qiskit, IBM's quantum computing language. Then we will need to import qiskits tools for creating Bloch sphere representations of qubits.

# %%
pip install qiskit
# Out:
# Requirement already satisfied: qiskit in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (0.43.3)
# Requirement already satisfied: qiskit-terra==0.24.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit) (0.24.2)
# Requirement already satisfied: qiskit-aer==0.12.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit) (0.12.2)
# Requirement already satisfied: qiskit-ibmq-provider==0.20.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit) (0.20.2)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-aer==0.12.2->qiskit) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-aer==0.12.2->qiskit) (1.11.1)
# Requirement already satisfied: requests>=2.19 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (2.27.1)
# Requirement already satisfied: requests-ntlm<=1.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.1.0)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.26.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.6.1)
# Requirement already satisfied: websockets>=10.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (11.0.3)
# Requirement already satisfied: rustworkx>=0.12.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.24.2->qiskit) (0.13.0)
# Requirement already satisfied: ply>=3.10 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.24.2->qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.24.2->qiskit) (5.9.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.24.2->qiskit) (1.12)
# Requirement already satisfied: dill>=0.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.24.2->qiskit) (0.3.6)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.24.2->qiskit) (5.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (3.3)
# Requirement already satisfied: ntlm-auth>=1.0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (41.0.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stevedore>=3.0.0->qiskit-terra==0.24.2->qiskit) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.3->qiskit-terra==0.24.2->qiskit) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Error parsing dependencies of bleach: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     tinycss2 (>=1.1.0<1.2) ; extra == 'css'
#              ~~~~~~~~^

# %%
import numpy as np
from qiskit import *
from qiskit.visualization import plot_bloch_vector
# %matplotlib inline

# %% [markdown]
# ## Qubits, the Bloch Sphere, and Basis States

# %% [markdown]
# Qubits are the basic unit of computation in a quantum computer, much like bits are the basic unit of computation in a "classical" computer. In bit based computing we have silicon chips with transistors which serve as "on/off" switches that serve as building blocks for complex systems of logic gates implementing Boolean logic. In a quantum computer, these "on/off" bits represented by strings of 0s and 1s are replaced by **qubits**. Qubits behave much differently from classical bits, but any classical computation involving bits can still be implemented on a quantum system of qubits. However, much more can be done qubits. They provide computational abilities that bits, classical computing, and classical information processing simply cannot replicate or accurately simulate. In some cases there are quantum information processes which provide a new paradigm for understanding information theory and computational complexity. Here we will focus on the basics and leave quantum complexity and subjects like entanglement entropy for the appendix at the end of the book on **tensor networks**.
#
# Qubits have many representations, the most common of them being as a $2$-dimensional complex unit vector:
#
# \begin{align}
# |\psi \rangle = \begin{pmatrix}
# \alpha \\ \beta
# \end{pmatrix}, \quad \text{where } \sqrt{\langle \psi | \psi \rangle} = 1.
# \end{align}
#
# From the condition that the vector be of length one, we can deduce the following:
#
# \begin{align}
# \sqrt{\langle \psi | \psi \rangle} &= \begin{pmatrix} \alpha^*, & \beta^* \end{pmatrix}\begin{pmatrix} \alpha \\ \beta \end{pmatrix} \\
# &= \sqrt{\alpha^* \alpha+ \beta^* \beta}\\
# &= \sqrt{|\alpha|^2 +|\beta|^2} = 1 \implies |\alpha|^2 +|\beta|^2 = 1.
# \end{align}
#
# Remember, $\alpha$ and $\beta$ are complex numbers (elements of $\mathbb{C}$), and so the vector $|\psi \rangle \in \mathbb{C}^2$. The vectors representing qubit **[pure states](https://en.wikipedia.org/wiki/Quantum_state#Pure_states)** actually live on the **Riemann sphere** also called the **[complex projective line](https://en.wikipedia.org/wiki/Riemann_sphere#As_the_complex_projective_line)** $\mathbb{P}^1(\mathbb{C})$.
#
# The second representation, which comes from the representation of pure states as points on the Riemann sphere and that is very common in the literature and in software packages for quantum computing is via the **[Bloch sphere](https://en.wikipedia.org/wiki/Bloch_sphere)**, named after the Nobel laureate and physicist [Felix Bloch](https://en.wikipedia.org/wiki/Felix_Bloch). Generally, the north pole represents the basis state
#
# \begin{align}
# |0\rangle = \begin{pmatrix} 1\\0 \end{pmatrix}
# \end{align}
#
# We can visualize this in Qiskit as follows:

# %%
plot_bloch_vector([0,0,1], title="Spin-Up")

# %% [markdown]
# ## Pauli Basis States
#
# In general we have the following six basis states in terms of the "**Puali matrices**" which we will define later.
#
# ### Spin-up/Spin-down (z-axis)
#
# \begin{align}
# \text{spin-up}: \ |0\rangle &= \begin{pmatrix} 1\\0 \end{pmatrix} \\
# \text{spin-down}: \ |1\rangle & = \begin{pmatrix} 0\\1 \end{pmatrix}
# \end{align}

# %%
plot_bloch_vector([0,0,1], title="Spin-Up")

# %%
plot_bloch_vector([0,0,-1], title="Spin-Down")

# %% [markdown]
# ### Spin-right/Spin-left (x-axis)
#
# \begin{align}
# \text{spin-right}: \ |r\rangle &= \begin{pmatrix} 1/\sqrt{2} \\ i/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle + i|1\rangle\right) \\
# \text{spin-left}: \ |l\rangle & = \begin{pmatrix} 1/\sqrt{2} \\ -i/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle - i|1\rangle\right)
# \end{align}

# %%
plot_bloch_vector([0,1,0], title="Spin-Right")

# %%
plot_bloch_vector([0,-1,0], title="Spin-Left")

# %% [markdown]
# ### Spin +/Spin - (y-axis)
#
# \begin{align}
# \text{spin +}: \ |+\rangle &= \begin{pmatrix} 1/\sqrt{2} \\ 1/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle + |1\rangle\right) \\
# \text{spin -}: \ |-\rangle & = \begin{pmatrix} 1/\sqrt{2} \\ -1/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle - |1\rangle\right)
# \end{align}

# %%
plot_bloch_vector([1,0,0], title="Spin-Plus")

# %%
plot_bloch_vector([-1,0,0], title="Spin-Minus")

# %% [markdown]
# ### Arbitrary State Vectors

# %% [markdown]
# If we want to define an arbitrary sate vector on the Bloch sphere we simply need to define a unit vector in $3$-dimensional space as the input state. To do this, define any $3$-dimensional vector, then divide it by its length (or norm). This will give a vector of length one, which can then be used as an input for Qiskit to plot on the Bloch sphere.
#
# An arbitrary pure state can be represented as some linear combination:
#
# \begin{align}
# |\psi \rangle =
# \begin{pmatrix}
# \alpha \\ \beta
# \end{pmatrix} = \alpha |0\rangle + \beta |1\rangle
# \end{align}
#
# where $|\alpha|^2 + |\beta|^2 = 1$.

# %%
# Define a 3-dimensional vector
vect = np.array([1, -1, 1])

# Divide it by its length (or norm)
psi = vect/(np.linalg.norm(vect))
print(psi)
# Out:
# [ 0.57735027 -0.57735027  0.57735027]

# %%
# Plot psi on the Bloch sphere using Qiskit
plot_bloch_vector(psi, title="psi")

# %% [markdown]
# We could also use *spherical coordinates* to define a unit vector that always lies on the surface of the unit sphere in $3$-dimensions, which is the Bloch sphere. To do this, we choose $\rho = 1$, and then choose two angles $\phi \in [0, \pi]$ and $\theta \in [0, 2\pi]$. The $x, y,$ and $z$ coordinates are then:
#
# \begin{align}
# x &= \rho \sin(\phi) \cos(\theta) \\
# y &= \rho \sin(\phi) \sin(\theta) \\
# z &= \rho \cos(\phi)
# \end{align}

# %% [markdown]
# Let do an example with $\phi = 0$ and $\theta = 0$. This should correspond to spin-up since we get
#
# \begin{align}
# x &= 0 \\
# y &= 0 \\
# z &= 1
# \end{align}

# %%
# Spin up state using spherical coordinates 
x = np.sin(0)*np.cos(0)
y = np.sin(0)*np.sin(0)
z = np.cos(0)

# Assigning x, y, z to psi1
psi1 = np.array([x, y, z])

# Showing spherical coordinates 
print("x=", x)
print("y=", y)
print("z=", z)
print("psi1=", psi1)
# Out:
# x= 0.0
# y= 0.0
# z= 1.0
# psi1= [0. 0. 1.]

# %%
# Plot psi on the Bloch sphere using Qiskit
plot_bloch_vector(psi1, title="psi1")

# %% [markdown]
# Let's try to use spherical coordinates to create the spin-down state now.

# %%
# Spin down state using spherical coordinates 
x = np.sin(0)*np.cos(np.pi)
y = np.sin(0)*np.sin(np.pi)
z = np.cos(np.pi)

# Assigning x, y, z to psi2
psi2 = np.array([x, y, z])

# Showing spherical coordinates 
print("x=", x)
print("y=", y)
print("z=", z)
print("psi2=", psi2)
# Out:
# x= -0.0
# y= 0.0
# z= -1.0
# psi2= [-0.  0. -1.]

# %%
# Plot psi on the Bloch sphere using Qiskit
plot_bloch_vector(psi2, title="psi2")

# %% [markdown]
# Let's define the six basis states in Python and compute some things with them.

# %%
# Spin up state
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state
spin_down = np.matrix([[0],
                     [1]])

# Spin right state
spin_right = (1/np.sqrt(2))*(spin_up + 1j*spin_down)

# Spin left state
spin_left = (1/np.sqrt(2))*(spin_up - 1j*spin_down)

# Spin + state
spin_plus = (1/np.sqrt(2))*(spin_up + spin_down)

# Spin - state
spin_minus = (1/np.sqrt(2))*(spin_up - spin_down)

# Showing all the 6 states 
print('spin up:', spin_up)
print('spin down:', spin_down)
print('spin right:', spin_right)
print('spin left:', spin_left)
print('spin plus:', spin_plus)
print('spin minus:', spin_minus)
# Out:
# spin up: [[1]
#  [0]]
# spin down: [[0]
#  [1]]
# spin right: [[0.70710678+0.j        ]
#  [0.        +0.70710678j]]
# spin left: [[0.70710678+0.j        ]
#  [0.        -0.70710678j]]
# spin plus: [[0.70710678]
#  [0.70710678]]
# spin minus: [[ 0.70710678]
#  [-0.70710678]]

# %%
# Dot product of spin down hermitian state and spin down state 
np.dot(spin_down.H, spin_down)
# Out:
# matrix([[1]])

# %%
# Dot product of spin left hermitian state and spin right state 
np.dot(spin_left.H, spin_right)
# Out:
# matrix([[0.+0.j]])

# %% [markdown]
# ## Exercises
#
# Compute the following inner products.
#
# 1. $\langle 0 | 1 \rangle$
# 2. $\langle 1 | 0 \rangle$
# 3. $\langle 1 | 1 \rangle$
# 4. $\langle r | l \rangle$
# 5. $\langle l | r \rangle$
# 6. $\langle r | r \rangle$
# 7. $\langle l | l \rangle$
# 8. $\langle + | - \rangle$
# 9. $\langle + | r \rangle$
# 10. $\langle - | l \rangle$
# 11. $\langle 0 | r \rangle$
# 12. $\langle l | 1 \rangle$
# 13. $\langle 0 | + \rangle$
# 14. $\langle - | - \rangle$
# 15. $\langle - | r \rangle$

# %% [markdown]
# Plot the following states on the Bloch sphere using Qiskit for the given angles $\phi$ and $\theta$.
#
# 16. $\phi = \pi/2$, $\theta = -\pi/3$.
# 17. $\phi = -\pi/4$, $\theta = -\pi/6$.
# 18. $\phi = -\pi/2$, $\theta = \pi/4$.
# 19. $\phi = \pi/3$, $\theta = -\pi$.
# 20. $\phi = -\pi/6$, $\theta = -\pi/4$.

# %% [markdown]
# ### Inner product

# %%
# 1

# Spin up state
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])

# Inner product of spin up hermitian conjugate state and spin down state 
np.dot(spin_up.H, spin_down)
# Out:
# matrix([[0]])

# %%
# 2

# Spin up state
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])

# Inner product of spin down hermitian conjugate state and spin up state 
np.dot(spin_down.H, spin_up)
# Out:
# matrix([[0]])

# %%
# 3 

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])
                    
# Inner product of spin down hermitian conjugate state and spin down state 
np.dot(spin_down.H, spin_down)
# Out:
# matrix([[1]])

# %%
# 4

# Spin up state
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])

# Spin right state
spin_right = (1/np.sqrt(2))*(spin_up + 1j*spin_down)

# Spin left state
spin_left = (1/np.sqrt(2))*(spin_up - 1j*spin_down)

# Inner product of spin right hermitian conjugate state and spin left state 
np.dot(spin_right.H, spin_left)
# Out:
# matrix([[0.+0.j]])

# %%
# 5

# Spin up state
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])

# Spin right state
spin_right = (1/np.sqrt(2))*(spin_up + 1j*spin_down)

# Spin left state
spin_left = (1/np.sqrt(2))*(spin_up - 1j*spin_down)

# Inner product of spin left hermitian conjugate state and spin right state 
np.dot(spin_left.H, spin_right)
# Out:
# matrix([[0.+0.j]])

# %%
# 6

# Spin up state
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])

# Spin right state
spin_right = (1/np.sqrt(2))*(spin_up + 1j*spin_down)

# Inner product of spin right hermitian conjugate state and spin right state 
np.dot(spin_right.H, spin_right)
# Out:
# matrix([[1.+0.j]])

# %%
# 7

# Spin up state
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])

# Spin left state
spin_left = (1/np.sqrt(2))*(spin_up - 1j*spin_down)

# Inner product of spin left hermitian conjugate state and spin left state 
np.dot(spin_left.H, spin_left)
# Out:
# matrix([[1.+0.j]])

# %%
# 8

# Spin up state
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])

# Spin + state 
spin_plus = (1/np.sqrt(2))*(spin_up + spin_down)

# Spin - state 
spin_minus = (1/np.sqrt(2))*(spin_up - spin_down)

# Inner product of spin + hermitian conjugate state and spin - state 
np.dot(spin_plus.H, spin_minus)
# Out:
# matrix([[0.]])

# %%
# 9

# Spin up state
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state
spin_down = np.matrix([[0],
                     [1]])

# Spin right state
spin_right = (1/np.sqrt(2))*(spin_up + 1j*spin_down)

# Spin + state 
spin_plus = (1/np.sqrt(2))*(spin_up + spin_down)

# Inner product of spin + hermitian conjugate state and spin right state 
np.dot(spin_plus.H, spin_right)
# Out:
# matrix([[0.5+0.5j]])

# %%
# 10

# Spin up state
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state
spin_down = np.matrix([[0],
                     [1]])

# Spin left state
spin_left = (1/np.sqrt(2))*(spin_up - 1j*spin_down)

# Spin - state 
spin_minus = (1/np.sqrt(2))*(spin_up - spin_down)

# Inner product of spin - hermitian conjugate state and spin left state 
np.dot(spin_minus.H, spin_left)
# Out:
# matrix([[0.5+0.5j]])

# %%
# 11

# Spin up state 
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])

# Spin right state 
spin_right = (1/np.sqrt(2))*(spin_up + 1j*spin_down)

# Spin left state 
spin_left = (1/np.sqrt(2))*(spin_up - 1j*spin_down)

# Inner product of spin up hermitian conjugate state and spin right state 
np.dot(spin_up.H, spin_right)
# Out:
# matrix([[0.70710678+0.j]])

# %%
# 12

# Spin up state 
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])

# Spin right state 
spin_right = (1/np.sqrt(2))*(spin_up + 1j*spin_down)

# Spin left state 
spin_left = (1/np.sqrt(2))*(spin_up - 1j*spin_down)

# Inner product of spin left hermitian conjugate state and spin down state 
np.dot(spin_left.H, spin_down)
# Out:
# matrix([[0.+0.70710678j]])

# %%
# 13

# Spin up state 
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])

# Spin + state 
spin_plus = (1/np.sqrt(2))*(spin_up + spin_down)

# Inner product of spin up hermitian conjugate state and spin plus state 
np.dot(spin_up.H, spin_plus)
# Out:
# matrix([[0.70710678]])

# %%
# 14 

# Spin - state 
spin_minus = (1/np.sqrt(2))*(spin_up - spin_down)

# Inner product of spin - hermitian conjugate state and spin - state 
np.dot(spin_minus.H, spin_minus)
# Out:
# matrix([[1.]])

# %%
# 15

# Spin up state 
spin_up = np.matrix([[1], 
                       [0]])

# Spin down state 
spin_down = np.matrix([[0],
                     [1]])

# Spin - state 
spin_minus = (1/np.sqrt(2))*(spin_up - spin_down)

# Spin right state 
spin_right = (1/np.sqrt(2))*(spin_up + 1j*spin_down)

# Inner product of spin - hermitian conjugate state and spin right state 
np.dot(spin_minus.H, spin_right)
# Out:
# matrix([[0.5-0.5j]])

# %% [markdown]
# ### Bloch Sphere

# %%
# 16

# Spin state using spherical coordinates 
x = np.sin(np.pi/2)*np.cos(-np.pi/3)
y = np.sin(np.pi/2)*np.sin(-np.pi/3)
z = np.cos(np.pi/2)

# Assigning x, y, z to psi_a
psi_a = np.array([x, y, z])
print("x=", x)
print("y=", y)
print("z=", z)
print("psi_a=", psi_a)

# Plot psi on the Bloch sphere
plot_bloch_vector(psi_a, title="psi_a")
# Out:
# x= 0.5000000000000001
# y= -0.8660254037844386
# z= 6.123233995736766e-17
# psi_a= [ 5.00000000e-01 -8.66025404e-01  6.12323400e-17]

# %%
# 17

# Spin state using spherical coordinates 
x = np.sin(-np.pi/4)*np.cos(-np.pi/6)
y = np.sin(-np.pi/4)*np.sin(-np.pi/6)
z = np.cos(-np.pi/4)

# Assigning x, y, z to psi_b
psi_b = np.array([x, y, z])
print("x=", x)
print("y=", y)
print("z=", z)
print("psi_b=", psi_b)

# Plot psi_b on the Bloch sphere
plot_bloch_vector(psi_b, title="psi_b")
# Out:
# x= -0.6123724356957946
# y= 0.35355339059327373
# z= 0.7071067811865476
# psi_b= [-0.61237244  0.35355339  0.70710678]

# %%
# 18

# Spin state using spherical coordinates 
x = np.sin(-np.pi/2)*np.cos(np.pi/4)
y = np.sin(-np.pi/2)*np.sin(np.pi/4)
z = np.cos(-np.pi/2)

# Assigning x, y, z to psi_b
psi_c = np.array([x, y, z])
print("x=", x)
print("y=", y)
print("z=", z)
print("psi_c=", psi_c)

# Plot psi_b on the Bloch sphere
plot_bloch_vector(psi_c, title="psi_c")
# Out:
# x= -0.7071067811865476
# y= -0.7071067811865476
# z= 6.123233995736766e-17
# psi_c= [-7.07106781e-01 -7.07106781e-01  6.12323400e-17]

# %%
# 19

# Spin state using spherical coordinates 
x = np.sin(np.pi/3)*np.cos(-np.pi)
y = np.sin(np.pi/3)*np.sin(-np.pi)
z = np.cos(np.pi/3)

# Assigning x, y, z to psi_b
psi_d = np.array([x, y, z])
print("x=", x)
print("y=", y)
print("z=", z)
print("psi_d=", psi_d)

# Plot psi_b on the Bloch sphere
plot_bloch_vector(psi_d, title="psi_d")
# Out:
# x= -0.8660254037844386
# y= -1.0605752387249068e-16
# z= 0.5000000000000001
# psi_d= [-8.66025404e-01 -1.06057524e-16  5.00000000e-01]

# %%
# 20

# Spin state using spherical coordinates 
x = np.sin(-np.pi/6)*np.cos(-np.pi/4)
y = np.sin(-np.pi/6)*np.sin(-np.pi/4)
z = np.cos(-np.pi/6)

# Assigning x, y, z to psi_b
psi_e = np.array([x, y, z])
print("x=", x)
print("y=", y)
print("z=", z)
print("psi_e=", psi_e)

# Plot psi_b on the Bloch sphere
plot_bloch_vector(psi_e, title="psi_e")
# Out:
# x= -0.35355339059327373
# y= 0.35355339059327373
# z= 0.8660254037844387
# psi_e= [-0.35355339  0.35355339  0.8660254 ]
